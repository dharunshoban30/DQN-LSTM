# %% [markdown]
# ## Load Libraries and Datasets
#
# ---------------------------------

# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from collections import deque
import random

import skopt
from skopt import gp_minimize
from skopt.space import Real, Integer
from skopt.utils import use_named_args

from tabulate import tabulate

# %%
amzn_df = pd.read_csv('AMZN_cleaned.csv')
googl_df = pd.read_csv('GOOGL_cleaned.csv')
msft_df = pd.read_csv('MSFT_cleaned.csv')

# %%
amzn_df.head()
# Out:
#       Open     High      Low    Close        SMA        EMA      MACD  \
# 0  14.1500  14.2100  13.3555  13.6380  13.426175  13.527232  0.161967
# 1  13.5520  13.7970  13.1850  13.2750  13.446650  13.488427  0.129849
# 2  13.4465  13.4465  13.1400  13.2500  13.462950  13.451746  0.101210
# 3  13.1390  13.2340  12.9535  12.9990  13.465025  13.382093  0.057597
# 4  13.1000  13.4015  13.0730  13.3445  13.461100  13.376309  0.050332
#
#    Signal Line
# 0     0.174111
# 1     0.165259
# 2     0.152449
# 3     0.133479
# 4     0.116849

# %%
googl_df.head()
# Out:
#         Open       High        Low      Close        SMA        EMA      MACD  \
# 0  18.862362  19.042793  18.841593  18.864614  18.346121  18.517347  0.163696
# 1  18.781532  18.959459  18.775024  18.911161  18.386712  18.577934  0.182985
# 2  18.973974  19.434435  18.971472  19.409409  18.451689  18.705853  0.235759
# 3  19.211460  19.281031  18.975725  18.994493  18.478028  18.750259  0.241321
# 4  19.047297  19.297047  19.005756  19.162663  18.516804  18.813706  0.256344
#
#    Signal Line
# 0     0.077188
# 1     0.098348
# 2     0.125830
# 3     0.148928
# 4     0.170411

# %%
msft_df.head()
# Out:
#         Open       High        Low      Close      SMA        EMA      MACD  \
# 0  28.010000  28.190001  27.760000  27.850000  27.2260  27.569285  0.130848
# 1  27.790001  27.969999  27.400000  27.450001  27.2175  27.550934  0.111640
# 2  27.670000  28.049999  27.549999  27.930000  27.2515  27.609251  0.133609
# 3  27.870001  28.020000  27.420000  27.440001  27.2865  27.583213  0.110211
# 4  27.620001  27.660000  27.360001  27.500000  27.3270  27.570411  0.095409
#
#    Signal Line
# 0     0.008465
# 1     0.029100
# 2     0.050002
# 3     0.062044
# 4     0.068717

# %% [markdown]
# ## Data Partitioning
#
# ----------------------------------------------------

# %% [markdown]
# ### Sequential Train-Test Split (80:20)

# %%
def split_train_test(data, train_size=0.8):
    split_index = int(len(data) * train_size)
    train_data = data.iloc[:split_index]
    test_data = data.iloc[split_index:]
    return train_data, test_data

# %% [markdown]
# ## Model Construction and Training
#
# ----------------------------------------------------

# %% [markdown]
# ### Trading Environment

# %%
class TradingEnv:
    def __init__(self, data, initial_capital=100):
        self.data = data
        self.state_space = ['Open', 'High', 'Low', 'Close', 'SMA', 'EMA', 'MACD', 'Signal Line']
        self.action_space = ['Sell', 'Hold', 'Buy']
        self.initial_capital = initial_capital
        self.reset()

    def reset(self):
        self.current_step = 0
        self.portfolio_value = self.initial_capital
        self.holding = False
        self.buy_price = 0.0

    def step(self, action):
        current_price = self.data['Close'].iloc[self.current_step]
        reward = 0

        if action == 2:  # Buy
            if not self.holding:
                self.buy_price = current_price
                self.holding = True

        elif action == 0:  # Sell
            if self.holding:
                reward = current_price - self.buy_price
                self.portfolio_value += reward
                self.holding = False

        self.current_step += 1
        done = self.current_step == len(self.data) - 1

        return reward, done

    def get_state(self):
        return self.data.iloc[self.current_step][self.state_space].values

    def get_portfolio_value(self):
        return self.portfolio_value

# %% [markdown]
# ### DQN-LSTM Model

# %%
class DQN_LSTM(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super(DQN_LSTM, self).__init__()
        self.hidden_dim = hidden_dim 
        self.lstm = nn.LSTM(input_dim, hidden_dim, batch_first=True)
        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, x):
        h_0 = torch.zeros(1, x.size(0), self.hidden_dim).to(x.device)
        c_0 = torch.zeros(1, x.size(0), self.hidden_dim).to(x.device)
        out, _ = self.lstm(x, (h_0, c_0))
        out = self.fc(out[:, -1, :])
        return out

# %% [markdown]
# ### Training and Testing Function

# %%
def evaluate_dqn_lstm(env, model, optimizer, criterion, num_episodes=5, batch_size=64, gamma=0.95, 
                      epsilon=1.0, epsilon_decay=0.995, epsilon_min=0.01, training=True):
    memory = deque(maxlen=2000)
    best_portfolio_value = 0
    best_portfolio_values = []

    for episode in range(num_episodes):
        env.reset()
        state = torch.tensor(np.array([env.get_state()]), dtype=torch.float32).to(device)
        total_reward = 0
        portfolio_values = [env.get_portfolio_value()]

        while True:
            if np.random.rand() <= epsilon:
                action = np.random.choice(len(env.action_space))
            else:
                with torch.no_grad():
                    q_values = model(state.unsqueeze(0))
                    action = torch.argmax(q_values).item()

            reward, done = env.step(action)
            total_reward += reward
            next_state = torch.tensor([env.get_state()], dtype=torch.float32).to(device)
            memory.append((state, action, reward, next_state, done))
            state = next_state

            portfolio_values.append(env.get_portfolio_value())

            if done:
                final_portfolio_value = env.get_portfolio_value()
                if final_portfolio_value > best_portfolio_value:
                    best_portfolio_value = final_portfolio_value
                    best_portfolio_values = portfolio_values
                print(f"Episode {episode + 1}/{num_episodes}, Total Reward: {total_reward}, Portfolio Value: {final_portfolio_value}")
                break

            if training and len(memory) > batch_size:
                batch = random.sample(memory, batch_size)
                for s, a, r, s_next, d in batch:
                    q_update = r
                    if not d:
                        q_update = (r + gamma * torch.max(model(s_next.unsqueeze(0))).item())
                    q_values = model(s.unsqueeze(0))
                    q_values[0][a] = q_update
                    optimizer.zero_grad()
                    loss = criterion(model(s.unsqueeze(0)), q_values)
                    loss.backward()
                    optimizer.step()

        if training and epsilon > epsilon_min:
            epsilon *= epsilon_decay

    return model, best_portfolio_value, best_portfolio_values

# %% [markdown]
# ### Performance Metrics Function

# %%
def calculate_performance_metrics(portfolio_values, risk_free_rate=0.01):
    portfolio_values = np.array(portfolio_values)

    # Cumulative Return
    initial_value = portfolio_values[0]
    final_value = portfolio_values[-1]
    cumulative_return = ((final_value - initial_value) / initial_value) * 100

    # Sharpe Ratio
    returns = np.diff(portfolio_values) / portfolio_values[:-1]
    excess_returns = returns - risk_free_rate / 252  # Convert annual risk-free rate to daily
    mean_excess_return = np.mean(excess_returns)
    std_excess_return = np.std(excess_returns)
    if std_excess_return != 0:
        sharpe_ratio = mean_excess_return / std_excess_return * np.sqrt(252)
    else:
        sharpe_ratio = np.nan  # Avoid division by zero

    # Maximum Drawdown
    peak_values = np.maximum.accumulate(portfolio_values)
    drawdowns = (peak_values - portfolio_values) / peak_values
    maximum_drawdown = drawdowns.max() * 100

    return cumulative_return, sharpe_ratio, maximum_drawdown

# %% [markdown]
# ## Model Evaluation
#
# ----------------------------------------------------

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
results = []

input_dim = len(['Open', 'High', 'Low', 'Close', 'SMA', 'EMA', 'MACD', 'Signal Line'])
hidden_dim = 64
output_dim = 3  # Buy, Sell, Hold
learning_rate = 0.001

datasets = {
    'AMZN': amzn_df,
    'GOOGL': googl_df,
    'MSFT': msft_df
}

for name, data in datasets.items():
    # Clean the data to remove any infinities or NaNs
    data.replace([np.inf, -np.inf], np.nan, inplace=True)
    data.dropna(inplace=True)

    # Split data into training and testing sets using the function
    train_data, test_data = split_train_test(data)

    # Train the model on the training set
    train_env = TradingEnv(train_data, initial_capital=100)
    model = DQN_LSTM(input_dim, hidden_dim, output_dim).to(device)
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)
    criterion = nn.MSELoss()
    model, _, _ = evaluate_dqn_lstm(train_env, model, optimizer, criterion, training=True)


    # Evaluate the model on the testing set
    test_env = TradingEnv(test_data, initial_capital=100)
    _, best_portfolio_value, best_portfolio_values = evaluate_dqn_lstm(test_env, model, optimizer, criterion, training=False)

    # Evaluate the model using the best portfolio values achieved
    final_portfolio_value = best_portfolio_value
    initial_capital = test_env.initial_capital

    total_profits = final_portfolio_value - initial_capital
    cr, sr, mdd = calculate_performance_metrics(best_portfolio_values)

    results.append({
        'Dataset': name,
        'Initial Capital': initial_capital,
        'Final Portfolio Value': final_portfolio_value,
        'Total Profits ($)': total_profits,
        'Cumulative Return (%)': cr,
        'Sharpe Ratio': sr,
        'Maximum Drawdown (%)': mdd
    })

results_df = pd.DataFrame(results)

# Display the results DataFrame
print(results_df)
# Out:
# Episode 1/5, Total Reward: 180.33197099999995, Portfolio Value: 280.33197099999984
# Episode 2/5, Total Reward: 77.970026, Portfolio Value: 177.97002599999993
# Episode 3/5, Total Reward: 81.85746899999995, Portfolio Value: 181.85746899999998
# Episode 4/5, Total Reward: 21.579003999999983, Portfolio Value: 121.57900400000004
# Episode 5/5, Total Reward: 112.41790699999996, Portfolio Value: 212.41790699999987
# Episode 1/5, Total Reward: 27.608016000000063, Portfolio Value: 127.60801600000012
# Episode 2/5, Total Reward: 29.466445999999905, Portfolio Value: 129.4664459999999
# Episode 3/5, Total Reward: -13.527983999999961, Portfolio Value: 86.47201600000004
# Episode 4/5, Total Reward: 48.45391100000003, Portfolio Value: 148.453911
# Episode 5/5, Total Reward: -52.50999800000008, Portfolio Value: 47.49000199999992
# Episode 1/5, Total Reward: 74.40878400000005, Portfolio Value: 174.40878400000014
# Episode 2/5, Total Reward: 42.54997299999993, Portfolio Value: 142.54997300000002
# Episode 3/5, Total Reward: 41.04643999999998, Portfolio Value: 141.04643999999996
# Episode 4/5, Total Reward: 27.548977000000026, Portfolio Value: 127.54897700000001
# Episode 5/5, Total Reward: 16.13103399999986, Portfolio Value: 116.13103399999996
# Episode 1/5, Total Reward: -36.555562000000094, Portfolio Value: 63.444437999999906
# Episode 2/5, Total Reward: -20.435992999999854, Portfolio Value: 79.56400700000015
# Episode 3/5, Total Reward: 28.74949499999984, Portfolio Value: 128.74949499999985
# Episode 4/5, Total Reward: -57.17756300000008, Portfolio Value: 42.82243699999992
# Episode 5/5, Total Reward: -25.621465999999984, Portfolio Value: 74.37853400000002
# Episode 1/5, Total Reward: 200.99991700000012, Portfolio Value: 300.9999170000003
# Episode 2/5, Total Reward: 167.98000699999983, Portfolio Value: 267.9800069999999
# Episode 3/5, Total Reward: 151.79009599999983, Portfolio Value: 251.79009599999983
# Episode 4/5, Total Reward: 125.07995800000003, Portfolio Value: 225.07995799999995
# Episode 5/5, Total Reward: 133.42012800000018, Portfolio Value: 233.4201280000001
# Episode 1/5, Total Reward: 170.98970300000022, Portfolio Value: 270.98970300000025
# Episode 2/5, Total Reward: 28.250029999999924, Portfolio Value: 128.25002999999992
# Episode 3/5, Total Reward: -15.049849000000023, Portfolio Value: 84.95015099999998
# Episode 4/5, Total Reward: 81.80993900000001, Portfolio Value: 181.809939
# Episode 5/5, Total Reward: -4.330026999999916, Portfolio Value: 95.66997300000008
#   Dataset  Initial Capital  Final Portfolio Value  Total Profits ($)  \
# 0    AMZN              100             148.453911          48.453911
# 1   GOOGL              100             128.749495          28.749495
# 2    MSFT              100             270.989703         170.989703
#
#    Cumulative Return (%)  Sharpe Ratio  Maximum Drawdown (%)
# 0              48.453911      0.865319             31.756736
# 1              28.749495      0.529728             20.416285
# 2             170.989703      1.396928             20.278057

# %% [markdown]
# ## Hyperparameter Optimization
#
# ----------------------------------------------------

# %% [markdown]
# ## Bayesian Optimization

# %%
# Bayesian Optimization
search_space = [
    Integer(32, 256, name='hidden_dim'),
    Real(1e-5, 1e-1, "log-uniform", name='learning_rate'),
    Real(0.8, 1.0, name='gamma'),
    Real(0.01, 1.0, name='epsilon_decay')
]

@use_named_args(search_space)
def objective(hidden_dim, learning_rate, gamma, epsilon_decay):
    hidden_dim = int(hidden_dim)  # Ensure hidden_dim is an integer
    model = DQN_LSTM(input_dim, hidden_dim, output_dim).to(device)
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)
    criterion = nn.MSELoss()

    # Train the model on the training data
    model, _, _ = evaluate_dqn_lstm(train_env, model, optimizer, criterion, gamma=gamma, epsilon_decay=epsilon_decay, training=True)

    # Test the model on the testing data
    test_env = TradingEnv(test_data, initial_capital=100)
    _, best_portfolio_value, best_portfolio_values = evaluate_dqn_lstm(test_env, model, optimizer, criterion, gamma=gamma, epsilon_decay=epsilon_decay, training=False)

    # Calculate cumulative return
    cr, _, _ = calculate_performance_metrics(best_portfolio_values)
    return -cr

results_bo = []

for name, data in datasets.items():
    data.replace([np.inf, -np.inf], np.nan, inplace=True)
    data.dropna(inplace=True)

    train_data, test_data = split_train_test(data)
    train_env = TradingEnv(train_data, initial_capital=100)

    res = gp_minimize(objective, search_space, n_calls=10, random_state=0)
    best_params = {dim.name: val for dim, val in zip(search_space, res.x)}

    hidden_dim = int(best_params['hidden_dim'])
    learning_rate = best_params['learning_rate']
    gamma = best_params['gamma']
    epsilon_decay = best_params['epsilon_decay']

    model = DQN_LSTM(input_dim, hidden_dim, output_dim).to(device)
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)
    criterion = nn.MSELoss()

    # Train the model on the training data
    model, _, _ = evaluate_dqn_lstm(train_env, model, optimizer, criterion, gamma=gamma, epsilon_decay=epsilon_decay, training=True)

    # Test the model on the testing data
    test_env = TradingEnv(test_data, initial_capital=100)
    _, best_portfolio_value, best_portfolio_values = evaluate_dqn_lstm(test_env, model, optimizer, criterion, gamma=gamma, epsilon_decay=epsilon_decay, training=False)

    final_portfolio_value = best_portfolio_value
    initial_capital = test_env.initial_capital

    total_profits = final_portfolio_value - initial_capital
    cr, sr, mdd = calculate_performance_metrics(best_portfolio_values)

    results_bo.append({
        'Dataset': name,
        'Initial Capital': initial_capital,
        'Final Portfolio Value': final_portfolio_value,
        'Total Profits ($)': total_profits,
        'Cumulative Return (%)': cr,
        'Sharpe Ratio': sr,
        'Maximum Drawdown (%)': mdd,
        'Best Params': best_params
    })
# Out:
# Episode 1/5, Total Reward: 49.139976000000146, Portfolio Value: 149.13997600000025
# Episode 2/5, Total Reward: 46.017896000000164, Portfolio Value: 146.01789600000012
# Episode 3/5, Total Reward: 64.43655100000001, Portfolio Value: 164.43655099999995
# Episode 4/5, Total Reward: 6.569532000000159, Portfolio Value: 106.56953200000027
# Episode 5/5, Total Reward: 52.51956899999992, Portfolio Value: 152.51956900000002
# Episode 1/5, Total Reward: 0.8495100000001798, Portfolio Value: 100.84951000000018
# Episode 2/5, Total Reward: -10.048981999999882, Portfolio Value: 89.95101800000012
# Episode 3/5, Total Reward: -79.37297000000001, Portfolio Value: 20.62702999999992
# Episode 4/5, Total Reward: 16.734978999999925, Portfolio Value: 116.73497899999992
# Episode 5/5, Total Reward: -20.03351000000012, Portfolio Value: 79.96648999999988
# Episode 1/5, Total Reward: 86.14263500000003, Portfolio Value: 186.14263500000004
# Episode 2/5, Total Reward: 81.21907100000006, Portfolio Value: 181.21907100000013
# Episode 3/5, Total Reward: 60.622045000000114, Portfolio Value: 160.62204500000004
# Episode 4/5, Total Reward: 40.671544000000026, Portfolio Value: 140.671544
# Episode 5/5, Total Reward: 55.20753700000007, Portfolio Value: 155.207537
# Episode 1/5, Total Reward: 37.52091999999996, Portfolio Value: 137.52091999999996
# Episode 2/5, Total Reward: -21.70588499999984, Portfolio Value: 78.29411500000016
# Episode 3/5, Total Reward: 8.340571999999966, Portfolio Value: 108.34057199999997
# Episode 4/5, Total Reward: -112.9555160000001, Portfolio Value: -12.95551600000013
# Episode 5/5, Total Reward: -11.080503000000036, Portfolio Value: 88.91949699999996
# Episode 1/5, Total Reward: 19.977564, Portfolio Value: 119.9775639999998
# Episode 2/5, Total Reward: 24.108513999999914, Portfolio Value: 124.10851399999999
# Episode 3/5, Total Reward: 42.74046900000006, Portfolio Value: 142.74046900000008
# Episode 4/5, Total Reward: 20.185455999999903, Portfolio Value: 120.18545599999989
# Episode 5/5, Total Reward: 30.112056999999965, Portfolio Value: 130.11205700000002
# Episode 1/5, Total Reward: -22.84093799999995, Portfolio Value: 77.15906200000005
# Episode 2/5, Total Reward: -23.74851200000009, Portfolio Value: 76.25148799999991
# Episode 3/5, Total Reward: 9.692483999999794, Portfolio Value: 109.6924839999998
# Episode 4/5, Total Reward: 68.35096199999994, Portfolio Value: 168.35096199999984
# Episode 5/5, Total Reward: 1.7314530000001298, Portfolio Value: 101.73145300000013
# Episode 1/5, Total Reward: -10.971978999999912, Portfolio Value: 89.02802100000008
# Episode 2/5, Total Reward: 112.03255299999988, Portfolio Value: 212.03255300000012
# Episode 3/5, Total Reward: -0.1914170000000226, Portfolio Value: 99.80858299999991
# Episode 4/5, Total Reward: 25.98257700000009, Portfolio Value: 125.98257700000008
# Episode 5/5, Total Reward: 87.42946899999995, Portfolio Value: 187.4294690000002
# Episode 1/5, Total Reward: -16.29654400000004, Portfolio Value: 83.70345599999996
# Episode 2/5, Total Reward: -24.126522000000136, Portfolio Value: 75.87347799999986
# Episode 3/5, Total Reward: -30.155522000000005, Portfolio Value: 69.844478
# Episode 4/5, Total Reward: 10.54045500000015, Portfolio Value: 110.54045500000015
# Episode 5/5, Total Reward: -37.00242100000021, Portfolio Value: 62.99757899999979
# Episode 1/5, Total Reward: 28.73245500000008, Portfolio Value: 128.73245500000013
# Episode 2/5, Total Reward: 82.60248599999983, Portfolio Value: 182.6024859999998
# Episode 3/5, Total Reward: 122.30752200000003, Portfolio Value: 222.30752200000032
# Episode 4/5, Total Reward: 53.03194800000017, Portfolio Value: 153.03194800000014
# Episode 5/5, Total Reward: 15.575463999999918, Portfolio Value: 115.57546399999973
# Episode 1/5, Total Reward: -68.23354000000003, Portfolio Value: 31.766459999999967
# Episode 2/5, Total Reward: 77.69504700000007, Portfolio Value: 177.69504700000002
# Episode 3/5, Total Reward: -45.62054700000003, Portfolio Value: 54.37945299999997
# Episode 4/5, Total Reward: -13.259868000000111, Portfolio Value: 86.74013199999989
# Episode 5/5, Total Reward: 34.705502000000166, Portfolio Value: 134.70550200000017
# Episode 1/5, Total Reward: 51.67848000000007, Portfolio Value: 151.67848000000006
# Episode 2/5, Total Reward: 46.05553200000004, Portfolio Value: 146.05553199999994
# Episode 3/5, Total Reward: 14.79105400000008, Portfolio Value: 114.79105400000017
# Episode 4/5, Total Reward: 103.75356900000016, Portfolio Value: 203.7535690000002
# Episode 5/5, Total Reward: 57.880409000000206, Portfolio Value: 157.8804090000003
# Episode 1/5, Total Reward: 23.25352400000007, Portfolio Value: 123.25352400000007
# Episode 2/5, Total Reward: -55.51197699999997, Portfolio Value: 44.48802300000003
# Episode 3/5, Total Reward: 15.374985000000024, Portfolio Value: 115.37498500000002
# Episode 4/5, Total Reward: 10.568543000000219, Portfolio Value: 110.56854300000022
# Episode 5/5, Total Reward: -19.070528999999965, Portfolio Value: 80.92947100000004
# Episode 1/5, Total Reward: 131.86345699999998, Portfolio Value: 231.86345699999998
# Episode 2/5, Total Reward: 105.448489, Portfolio Value: 205.44848899999988
# Episode 3/5, Total Reward: 95.85996699999984, Portfolio Value: 195.8599669999999
# Episode 4/5, Total Reward: 45.20047399999997, Portfolio Value: 145.2004739999999
# Episode 5/5, Total Reward: 55.222521999999884, Portfolio Value: 155.2225219999999
# Episode 1/5, Total Reward: -3.0045110000000363, Portfolio Value: 96.99548899999996
# Episode 2/5, Total Reward: -10.655001000000055, Portfolio Value: 89.34499899999994
# Episode 3/5, Total Reward: -38.88200500000001, Portfolio Value: 61.11799499999999
# Episode 4/5, Total Reward: -4.842053000000121, Portfolio Value: 95.15794699999988
# Episode 5/5, Total Reward: 38.5873890000001, Portfolio Value: 138.58738900000012
# Episode 1/5, Total Reward: 76.51297900000017, Portfolio Value: 176.51297900000017
# Episode 2/5, Total Reward: 102.81183200000018, Portfolio Value: 202.81183200000018
# Episode 3/5, Total Reward: 58.36742400000003, Portfolio Value: 158.36742400000009
# Episode 4/5, Total Reward: 24.56909699999986, Portfolio Value: 124.56909699999979
# Episode 5/5, Total Reward: 4.458046000000056, Portfolio Value: 104.45804600000007
# Episode 1/5, Total Reward: 19.996006999999906, Portfolio Value: 119.9960069999999
# Episode 2/5, Total Reward: -46.302061000000066, Portfolio Value: 53.697938999999934
# Episode 3/5, Total Reward: -23.64442100000008, Portfolio Value: 76.35557899999992
# Episode 4/5, Total Reward: 12.947979999999959, Portfolio Value: 112.94797999999996
# Episode 5/5, Total Reward: -5.2250050000000385, Portfolio Value: 94.77499499999996
# Episode 1/5, Total Reward: 107.3215659999999, Portfolio Value: 207.32156600000008
# Episode 2/5, Total Reward: 96.033972, Portfolio Value: 196.03397200000006
# Episode 3/5, Total Reward: 60.06800099999995, Portfolio Value: 160.06800099999995
# Episode 4/5, Total Reward: 93.70092600000001, Portfolio Value: 193.700926
# Episode 5/5, Total Reward: 67.72396000000005, Portfolio Value: 167.72395999999998
# Episode 1/5, Total Reward: 4.162041999999886, Portfolio Value: 104.16204199999989
# Episode 2/5, Total Reward: -16.224987999999968, Portfolio Value: 83.77501200000003
# Episode 3/5, Total Reward: -44.251960999999994, Portfolio Value: 55.748039000000006
# Episode 4/5, Total Reward: 42.095527999999845, Portfolio Value: 142.0955279999998
# Episode 5/5, Total Reward: 0.6770489999999825, Portfolio Value: 100.67704899999998
# Episode 1/5, Total Reward: 39.27602500000008, Portfolio Value: 139.27602500000017
# Episode 2/5, Total Reward: 36.04795799999995, Portfolio Value: 136.04795799999994
# Episode 3/5, Total Reward: 65.27406500000004, Portfolio Value: 165.27406500000006
# Episode 4/5, Total Reward: 52.386546999999894, Portfolio Value: 152.3865469999999
# Episode 5/5, Total Reward: 65.71003199999998, Portfolio Value: 165.71003199999987
# Episode 1/5, Total Reward: 49.93601700000016, Portfolio Value: 149.9360170000002
# Episode 2/5, Total Reward: 3.4789780000000263, Portfolio Value: 103.47897800000003
# Episode 3/5, Total Reward: 15.36696599999999, Portfolio Value: 115.36696599999999
# Episode 4/5, Total Reward: -6.254977000000011, Portfolio Value: 93.74502299999999
# Episode 5/5, Total Reward: 5.252954999999872, Portfolio Value: 105.25295499999987
# Episode 1/5, Total Reward: 140.6165129999998, Portfolio Value: 240.61651299999983
# Episode 2/5, Total Reward: 42.828951, Portfolio Value: 142.82895100000007
# Episode 3/5, Total Reward: 129.55249700000007, Portfolio Value: 229.55249700000013
# Episode 4/5, Total Reward: 90.08751199999979, Portfolio Value: 190.08751199999975
# Episode 5/5, Total Reward: 101.72892000000006, Portfolio Value: 201.72892000000004
# Episode 1/5, Total Reward: 34.053942999999975, Portfolio Value: 134.05394299999995
# Episode 2/5, Total Reward: -65.83046899999988, Portfolio Value: 34.16953100000012
# Episode 3/5, Total Reward: -28.726497999999978, Portfolio Value: 71.27350200000002
# Episode 4/5, Total Reward: -9.898423999999963, Portfolio Value: 90.10157600000004
# Episode 5/5, Total Reward: -11.981460999999967, Portfolio Value: 88.01853900000003
# Episode 1/5, Total Reward: 98.41021900000003, Portfolio Value: 198.41021900000007
# Episode 2/5, Total Reward: 59.612632999999974, Portfolio Value: 159.6126330000001
# Episode 3/5, Total Reward: 69.10604900000018, Portfolio Value: 169.10604900000016
# Episode 4/5, Total Reward: 71.89843099999993, Portfolio Value: 171.89843099999987
# Episode 5/5, Total Reward: 60.66118800000007, Portfolio Value: 160.66118800000004
# Episode 1/5, Total Reward: 34.99596699999998, Portfolio Value: 134.99596699999998
# Episode 2/5, Total Reward: -2.0945100000000707, Portfolio Value: 97.90548999999993
# Episode 3/5, Total Reward: 7.008973999999938, Portfolio Value: 107.00897399999994
# Episode 4/5, Total Reward: 9.924528999999964, Portfolio Value: 109.92452899999996
# Episode 5/5, Total Reward: 20.17048700000005, Portfolio Value: 120.17048700000005
# Episode 1/5, Total Reward: 60.70048699999998, Portfolio Value: 160.70048700000015
# Episode 2/5, Total Reward: 58.31682300000002, Portfolio Value: 158.31682300000006
# Episode 3/5, Total Reward: 45.2465219999999, Portfolio Value: 145.24652199999986
# Episode 4/5, Total Reward: 38.26497799999999, Portfolio Value: 138.26497799999999
# Episode 5/5, Total Reward: 21.04034500000003, Portfolio Value: 121.04034500000006
# Episode 1/5, Total Reward: -13.388084999999975, Portfolio Value: 86.61191500000002
# Episode 2/5, Total Reward: 30.154462000000024, Portfolio Value: 130.15446200000002
# Episode 3/5, Total Reward: 5.903020999999811, Portfolio Value: 105.90302099999981
# Episode 4/5, Total Reward: -22.960901000000035, Portfolio Value: 77.03909899999996
# Episode 5/5, Total Reward: 1.769529999999861, Portfolio Value: 101.76952999999986
# Episode 1/5, Total Reward: 54.631372999999954, Portfolio Value: 154.63137299999983
# Episode 2/5, Total Reward: 36.87831600000003, Portfolio Value: 136.87831600000007
# Episode 3/5, Total Reward: 60.46932099999998, Portfolio Value: 160.46932099999998
# Episode 4/5, Total Reward: 36.485470999999976, Portfolio Value: 136.48547099999993
# Episode 5/5, Total Reward: 26.209208999999976, Portfolio Value: 126.20920899999999
# Episode 1/5, Total Reward: 26.77742199999993, Portfolio Value: 126.77742199999993
# Episode 2/5, Total Reward: -14.782008999999988, Portfolio Value: 85.21799100000001
# Episode 3/5, Total Reward: -45.1419820000001, Portfolio Value: 54.8580179999999
# Episode 4/5, Total Reward: 2.099006000000017, Portfolio Value: 102.09900600000002
# Episode 5/5, Total Reward: 40.47846499999993, Portfolio Value: 140.47846499999991
# Episode 1/5, Total Reward: 64.3065850000001, Portfolio Value: 164.30658499999993
# Episode 2/5, Total Reward: 55.487919999999995, Portfolio Value: 155.48792000000017
# Episode 3/5, Total Reward: 36.44189699999997, Portfolio Value: 136.441897
# Episode 4/5, Total Reward: 44.315312000000105, Portfolio Value: 144.3153120000001
# Episode 5/5, Total Reward: 48.83242699999997, Portfolio Value: 148.83242699999985
# Episode 1/5, Total Reward: -54.34499600000005, Portfolio Value: 45.65500399999995
# Episode 2/5, Total Reward: -25.891567999999992, Portfolio Value: 74.10843200000001
# Episode 3/5, Total Reward: 41.600029000000006, Portfolio Value: 141.600029
# Episode 4/5, Total Reward: -53.141995000000065, Portfolio Value: 46.858004999999935
# Episode 5/5, Total Reward: 18.468885999999955, Portfolio Value: 118.46888599999996
# Episode 1/5, Total Reward: 50.32388599999999, Portfolio Value: 150.32388599999996
# Episode 2/5, Total Reward: 63.71224300000003, Portfolio Value: 163.712243
# Episode 3/5, Total Reward: 15.918741000000015, Portfolio Value: 115.91874099999998
# Episode 4/5, Total Reward: 95.59671699999996, Portfolio Value: 195.59671699999984
# Episode 5/5, Total Reward: 37.906955999999894, Portfolio Value: 137.9069559999999
# Episode 1/5, Total Reward: 41.300506999999996, Portfolio Value: 141.300507
# Episode 2/5, Total Reward: 40.468529999999845, Portfolio Value: 140.4685299999999
# Episode 3/5, Total Reward: -43.37704199999989, Portfolio Value: 56.62295800000011
# Episode 4/5, Total Reward: -22.780062999999913, Portfolio Value: 77.21993700000009
# Episode 5/5, Total Reward: -48.237520999999944, Portfolio Value: 51.762479000000056
# Episode 1/5, Total Reward: 58.782295000000104, Portfolio Value: 158.78229500000015
# Episode 2/5, Total Reward: 55.10462300000012, Portfolio Value: 155.10462300000015
# Episode 3/5, Total Reward: 37.45860699999986, Portfolio Value: 137.45860699999974
# Episode 4/5, Total Reward: 47.083048, Portfolio Value: 147.083048
# Episode 5/5, Total Reward: 48.64610400000001, Portfolio Value: 148.64610399999992
# Episode 1/5, Total Reward: 53.734973999999866, Portfolio Value: 153.73497399999988
# Episode 2/5, Total Reward: -63.80551600000011, Portfolio Value: 36.19448399999989
# Episode 3/5, Total Reward: 9.418104000000014, Portfolio Value: 109.41810400000001
# Episode 4/5, Total Reward: 52.83056500000012, Portfolio Value: 152.83056500000012
# Episode 5/5, Total Reward: 5.773012000000094, Portfolio Value: 105.7730120000001
# Episode 1/5, Total Reward: 45.49409900000004, Portfolio Value: 145.49409899999995
# Episode 2/5, Total Reward: 38.06297500000004, Portfolio Value: 138.06297499999982
# Episode 3/5, Total Reward: 17.40574299999993, Portfolio Value: 117.40574299999993
# Episode 4/5, Total Reward: 59.82462899999999, Portfolio Value: 159.82462900000013
# Episode 5/5, Total Reward: 26.95294099999993, Portfolio Value: 126.95294099999984
# Episode 1/5, Total Reward: 52.586448999999945, Portfolio Value: 152.58644899999996
# Episode 2/5, Total Reward: 6.662976000000029, Portfolio Value: 106.66297600000003
# Episode 3/5, Total Reward: -52.52656899999987, Portfolio Value: 47.47343100000013
# Episode 4/5, Total Reward: -59.69895499999997, Portfolio Value: 40.30104500000003
# Episode 5/5, Total Reward: 10.736935000000145, Portfolio Value: 110.73693500000014
# Episode 1/5, Total Reward: 86.22965900000005, Portfolio Value: 186.22965899999994
# Episode 2/5, Total Reward: 28.486116999999894, Portfolio Value: 128.48611699999987
# Episode 3/5, Total Reward: 28.003233999999985, Portfolio Value: 128.00323399999994
# Episode 4/5, Total Reward: 90.694225, Portfolio Value: 190.69422500000002
# Episode 5/5, Total Reward: 35.449298000000056, Portfolio Value: 135.44929800000006
# Episode 1/5, Total Reward: -65.04352199999995, Portfolio Value: 34.95647800000005
# Episode 2/5, Total Reward: 10.028999999999996, Portfolio Value: 110.029
# Episode 3/5, Total Reward: -16.741475999999864, Portfolio Value: 83.25852400000014
# Episode 4/5, Total Reward: 18.73244499999994, Portfolio Value: 118.73244499999994
# Episode 5/5, Total Reward: -27.244496000000154, Portfolio Value: 72.75550399999985
# Episode 1/5, Total Reward: 63.725007999999846, Portfolio Value: 163.72500799999972
# Episode 2/5, Total Reward: 34.08552400000004, Portfolio Value: 134.08552400000005
# Episode 3/5, Total Reward: 54.020573999999904, Portfolio Value: 154.0205739999999
# Episode 4/5, Total Reward: 32.781617000000004, Portfolio Value: 132.7816170000001
# Episode 5/5, Total Reward: 38.78936300000004, Portfolio Value: 138.7893630000001
# Episode 1/5, Total Reward: 50.20701200000002, Portfolio Value: 150.20701200000002
# Episode 2/5, Total Reward: 30.691980000000044, Portfolio Value: 130.69198000000006
# Episode 3/5, Total Reward: 15.692009999999968, Portfolio Value: 115.69200999999997
# Episode 4/5, Total Reward: -18.918484000000078, Portfolio Value: 81.08151599999992
# Episode 5/5, Total Reward: -30.272005000000078, Portfolio Value: 69.72799499999992
# Episode 1/5, Total Reward: 91.6081230000001, Portfolio Value: 191.6081230000001
# Episode 2/5, Total Reward: 30.228927000000024, Portfolio Value: 130.2289269999999
# Episode 3/5, Total Reward: 43.22195300000001, Portfolio Value: 143.22195300000007
# Episode 4/5, Total Reward: 22.48231299999996, Portfolio Value: 122.48231300000008
# Episode 5/5, Total Reward: 31.776312000000026, Portfolio Value: 131.77631199999993
# Episode 1/5, Total Reward: 43.51200400000006, Portfolio Value: 143.51200400000008
# Episode 2/5, Total Reward: 20.424045999999947, Portfolio Value: 120.42404599999993
# Episode 3/5, Total Reward: 7.533491000000041, Portfolio Value: 107.53349100000004
# Episode 4/5, Total Reward: 13.89702899999996, Portfolio Value: 113.89702899999996
# Episode 5/5, Total Reward: 26.730431999999894, Portfolio Value: 126.7304319999999
# Episode 1/5, Total Reward: 43.406379999999956, Portfolio Value: 143.40637999999996
# Episode 2/5, Total Reward: 60.58525399999985, Portfolio Value: 160.585254
# Episode 3/5, Total Reward: 48.77271299999997, Portfolio Value: 148.772713
# Episode 4/5, Total Reward: 70.31225900000005, Portfolio Value: 170.312259
# Episode 5/5, Total Reward: 49.490629000000155, Portfolio Value: 149.49062900000013
# Episode 1/5, Total Reward: 33.28658800000001, Portfolio Value: 133.286588
# Episode 2/5, Total Reward: -45.57652200000007, Portfolio Value: 54.42347799999993
# Episode 3/5, Total Reward: -27.60552, Portfolio Value: 72.39448
# Episode 4/5, Total Reward: -51.816479999999885, Portfolio Value: 48.183520000000115
# Episode 5/5, Total Reward: -3.8724589999999637, Portfolio Value: 96.12754100000004
# Episode 1/5, Total Reward: 109.41991400000003, Portfolio Value: 209.41991399999984
# Episode 2/5, Total Reward: 118.04991400000006, Portfolio Value: 218.04991400000006
# Episode 3/5, Total Reward: 103.0800389999999, Portfolio Value: 203.0800389999999
# Episode 4/5, Total Reward: 71.00010599999973, Portfolio Value: 171.00010599999973
# Episode 5/5, Total Reward: 141.06995699999982, Portfolio Value: 241.0699569999998
# Episode 1/5, Total Reward: 33.64001499999998, Portfolio Value: 133.64001499999998
# Episode 2/5, Total Reward: 9.889747999999969, Portfolio Value: 109.88974799999997
# Episode 3/5, Total Reward: 3.279843999999912, Portfolio Value: 103.27984399999991
# Episode 4/5, Total Reward: -5.899977999999976, Portfolio Value: 94.10002200000002
# Episode 5/5, Total Reward: 62.64001699999983, Portfolio Value: 162.64001699999983
# Episode 1/5, Total Reward: 132.86007099999992, Portfolio Value: 232.86007099999992
# Episode 2/5, Total Reward: 83.91009099999982, Portfolio Value: 183.91009099999977
# Episode 3/5, Total Reward: 82.72999000000003, Portfolio Value: 182.72998999999996
# Episode 4/5, Total Reward: 79.25996200000004, Portfolio Value: 179.2599620000001
# Episode 5/5, Total Reward: 8.879993999999968, Portfolio Value: 108.8799939999999
# Episode 1/5, Total Reward: 91.96012299999987, Portfolio Value: 191.96012299999987
# Episode 2/5, Total Reward: 10.00997099999995, Portfolio Value: 110.00997099999995
# Episode 3/5, Total Reward: 64.04012000000026, Portfolio Value: 164.04012000000026
# Episode 4/5, Total Reward: 32.06997699999977, Portfolio Value: 132.06997699999977
# Episode 5/5, Total Reward: 107.04994600000018, Portfolio Value: 207.04994600000018
# Episode 1/5, Total Reward: 195.62015200000013, Portfolio Value: 295.620152
# Episode 2/5, Total Reward: 140.64008299999986, Portfolio Value: 240.64008299999995
# Episode 3/5, Total Reward: 34.00995999999996, Portfolio Value: 134.00995999999992
# Episode 4/5, Total Reward: 12.069985000000145, Portfolio Value: 112.0699850000002
# Episode 5/5, Total Reward: 38.06997900000003, Portfolio Value: 138.06997899999996
# Episode 1/5, Total Reward: 70.7098959999999, Portfolio Value: 170.7098959999999
# Episode 2/5, Total Reward: 16.230037999999865, Portfolio Value: 116.23003799999987
# Episode 3/5, Total Reward: -14.730044000000106, Portfolio Value: 85.2699559999999
# Episode 4/5, Total Reward: 87.4698980000002, Portfolio Value: 187.4698980000002
# Episode 5/5, Total Reward: 67.07016200000015, Portfolio Value: 167.07016200000015
# Episode 1/5, Total Reward: 89.00989599999997, Portfolio Value: 189.00989599999997
# Episode 2/5, Total Reward: 75.17006100000012, Portfolio Value: 175.1700610000001
# Episode 3/5, Total Reward: 81.27008900000037, Portfolio Value: 181.2700890000003
# Episode 4/5, Total Reward: 132.30998000000005, Portfolio Value: 232.3099800000001
# Episode 5/5, Total Reward: 105.38999299999999, Portfolio Value: 205.38999299999995
# Episode 1/5, Total Reward: 11.590237999999744, Portfolio Value: 111.59023799999974
# Episode 2/5, Total Reward: -63.61019100000007, Portfolio Value: 36.38980899999993
# Episode 3/5, Total Reward: 24.23007400000003, Portfolio Value: 124.23007400000003
# Episode 4/5, Total Reward: 10.52989500000001, Portfolio Value: 110.52989500000001
# Episode 5/5, Total Reward: -47.90002299999989, Portfolio Value: 52.09997700000011
# Episode 1/5, Total Reward: 224.81011900000018, Portfolio Value: 324.81011900000016
# Episode 2/5, Total Reward: 27.570087, Portfolio Value: 127.57008700000003
# Episode 3/5, Total Reward: 170.15014200000002, Portfolio Value: 270.15014200000013
# Episode 4/5, Total Reward: 177.1500449999999, Portfolio Value: 277.1500449999999
# Episode 5/5, Total Reward: 126.93000099999995, Portfolio Value: 226.9300010000001
# Episode 1/5, Total Reward: 147.3299710000001, Portfolio Value: 247.3299710000001
# Episode 2/5, Total Reward: 123.9200710000002, Portfolio Value: 223.9200710000002
# Episode 3/5, Total Reward: -60.75976300000008, Portfolio Value: 39.24023699999992
# Episode 4/5, Total Reward: 8.480071000000038, Portfolio Value: 108.48007100000004
# Episode 5/5, Total Reward: -15.44001500000013, Portfolio Value: 84.55998499999987
# Episode 1/5, Total Reward: 143.18019999999993, Portfolio Value: 243.18019999999993
# Episode 2/5, Total Reward: 89.10988799999996, Portfolio Value: 189.10988799999996
# Episode 3/5, Total Reward: 120.14004900000027, Portfolio Value: 220.14004900000026
# Episode 4/5, Total Reward: 85.29998199999989, Portfolio Value: 185.2999819999998
# Episode 5/5, Total Reward: 102.20987999999994, Portfolio Value: 202.20988000000003
# Episode 1/5, Total Reward: 66.47989199999981, Portfolio Value: 166.4798919999998
# Episode 2/5, Total Reward: 59.20019300000004, Portfolio Value: 159.20019300000004
# Episode 3/5, Total Reward: 52.64000200000035, Portfolio Value: 152.64000200000035
# Episode 4/5, Total Reward: -16.310076000000265, Portfolio Value: 83.68992399999973
# Episode 5/5, Total Reward: 193.1298619999999, Portfolio Value: 293.1298619999999
# Episode 1/5, Total Reward: 111.78008499999972, Portfolio Value: 211.78008499999964
# Episode 2/5, Total Reward: 191.09002999999993, Portfolio Value: 291.09002999999984
# Episode 3/5, Total Reward: 88.06989800000012, Portfolio Value: 188.069898
# Episode 4/5, Total Reward: 33.599926000000096, Portfolio Value: 133.59992600000007
# Episode 5/5, Total Reward: 100.80001000000016, Portfolio Value: 200.8000100000002
# Episode 1/5, Total Reward: 22.809995999999813, Portfolio Value: 122.80999599999981
# Episode 2/5, Total Reward: -20.880048999999957, Portfolio Value: 79.11995100000004
# Episode 3/5, Total Reward: -43.37999199999976, Portfolio Value: 56.62000800000024
# Episode 4/5, Total Reward: -36.490038000000084, Portfolio Value: 63.509961999999916
# Episode 5/5, Total Reward: 143.67006200000023, Portfolio Value: 243.67006200000023
# Episode 1/5, Total Reward: 169.219924, Portfolio Value: 269.2199240000001
# Episode 2/5, Total Reward: 106.10008300000001, Portfolio Value: 206.100083
# Episode 3/5, Total Reward: 123.36989999999986, Portfolio Value: 223.3698999999999
# Episode 4/5, Total Reward: 57.25999499999993, Portfolio Value: 157.25999499999995
# Episode 5/5, Total Reward: 19.490004999999883, Portfolio Value: 119.49000499999988
# Episode 1/5, Total Reward: 90.64996099999993, Portfolio Value: 190.64996099999993
# Episode 2/5, Total Reward: -29.509886999999964, Portfolio Value: 70.49011300000004
# Episode 3/5, Total Reward: 99.44003299999986, Portfolio Value: 199.44003299999986
# Episode 4/5, Total Reward: -85.71978799999997, Portfolio Value: 14.280212000000034
# Episode 5/5, Total Reward: 6.029952999999836, Portfolio Value: 106.02995299999984
# Episode 1/5, Total Reward: 44.649911000000074, Portfolio Value: 144.64991100000015
# Episode 2/5, Total Reward: 156.089951, Portfolio Value: 256.0899510000001
# Episode 3/5, Total Reward: 115.37001199999997, Portfolio Value: 215.37001200000014
# Episode 4/5, Total Reward: 110.3000530000001, Portfolio Value: 210.3000530000001
# Episode 5/5, Total Reward: 70.10998900000006, Portfolio Value: 170.10998900000004
# Episode 1/5, Total Reward: 11.52996499999989, Portfolio Value: 111.52996499999989
# Episode 2/5, Total Reward: 86.08024599999999, Portfolio Value: 186.080246
# Episode 3/5, Total Reward: -45.77002400000018, Portfolio Value: 54.22997599999982
# Episode 4/5, Total Reward: 126.68997300000001, Portfolio Value: 226.689973
# Episode 5/5, Total Reward: 7.769854000000038, Portfolio Value: 107.76985400000004
# Episode 1/5, Total Reward: 103.49992300000022, Portfolio Value: 203.4999230000002
# Episode 2/5, Total Reward: 48.69001800000001, Portfolio Value: 148.69001800000012
# Episode 3/5, Total Reward: 67.27012899999994, Portfolio Value: 167.27012899999988
# Episode 4/5, Total Reward: 84.19002400000005, Portfolio Value: 184.19002400000005
# Episode 5/5, Total Reward: 20.23005699999984, Portfolio Value: 120.23005699999985
# Episode 1/5, Total Reward: -48.80993900000007, Portfolio Value: 51.19006099999993
# Episode 2/5, Total Reward: 96.9900079999999, Portfolio Value: 196.9900079999999
# Episode 3/5, Total Reward: 17.539953999999938, Portfolio Value: 117.53995399999994
# Episode 4/5, Total Reward: -25.00996299999997, Portfolio Value: 74.99003700000003
# Episode 5/5, Total Reward: 16.68997900000008, Portfolio Value: 116.68997900000008
# Episode 1/5, Total Reward: 169.7701720000001, Portfolio Value: 269.7701720000002
# Episode 2/5, Total Reward: 152.90996400000017, Portfolio Value: 252.9099640000002
# Episode 3/5, Total Reward: 152.88014199999992, Portfolio Value: 252.88014199999986
# Episode 4/5, Total Reward: 1.8400130000002832, Portfolio Value: 101.84001300000034
# Episode 5/5, Total Reward: 130.00008500000024, Portfolio Value: 230.00008500000038
# Episode 1/5, Total Reward: -57.530070999999964, Portfolio Value: 42.469929000000036
# Episode 2/5, Total Reward: 69.98986999999988, Portfolio Value: 169.98986999999988
# Episode 3/5, Total Reward: 139.07992699999994, Portfolio Value: 239.07992699999994
# Episode 4/5, Total Reward: -32.01998900000018, Portfolio Value: 67.98001099999982
# Episode 5/5, Total Reward: 98.62007199999988, Portfolio Value: 198.62007199999988

# %%
print(results_bo)
# Out:
# [{'Dataset': 'AMZN', 'Initial Capital': 100, 'Final Portfolio Value': 134.05394299999995, 'Total Profits ($)': 34.05394299999995, 'Cumulative Return (%)': 34.05394299999995, 'Sharpe Ratio': 0.5470904595942767, 'Maximum Drawdown (%)': 25.82482732190047, 'Best Params': {'hidden_dim': 114, 'learning_rate': 0.06739390723749777, 'gamma': 0.8280701560825291, 'epsilon_decay': 0.8713863857748523}}, {'Dataset': 'GOOGL', 'Initial Capital': 100, 'Final Portfolio Value': 133.286588, 'Total Profits ($)': 33.286587999999995, 'Cumulative Return (%)': 33.286587999999995, 'Sharpe Ratio': 0.5532137797793807, 'Maximum Drawdown (%)': 25.931165183615647, 'Best Params': {'hidden_dim': 138, 'learning_rate': 0.01598243724741151, 'gamma': 0.904095495910241, 'epsilon_decay': 0.6820907348177708}}, {'Dataset': 'MSFT', 'Initial Capital': 100, 'Final Portfolio Value': 239.07992699999994, 'Total Profits ($)': 139.07992699999994, 'Cumulative Return (%)': 139.07992699999994, 'Sharpe Ratio': 1.0243577849257843, 'Maximum Drawdown (%)': 36.45380156728608, 'Best Params': {'hidden_dim': 138, 'learning_rate': 0.01598243724741151, 'gamma': 0.904095495910241, 'epsilon_decay': 0.6820907348177708}}]

# %% [markdown]
# ## Results Analysis
#
# ----------------------------------------------------

# %%
# Extracting data for table display
table_data = []
for result in results_bo:
    row = [
        result['Dataset'],
        result['Initial Capital'],
        result['Final Portfolio Value'],
        result['Total Profits ($)'],
        result['Cumulative Return (%)'],
        result['Sharpe Ratio'],
        result['Maximum Drawdown (%)']
    ]
    table_data.append(row)

# Defining headers for the table
headers = [
    'Dataset',
    'Initial Capital',
    'Final Portfolio Value',
    'Total Profits ($)',
    'Cumulative Return (%)',
    'Sharpe Ratio',
    'Maximum Drawdown (%)'
]

# %%
# Display the combined DataFrame
print("Results without Bayesian Optimization: ")
display(results_df)
# Out:
# Results without Bayesian Optimization:
#   Dataset  Initial Capital  Final Portfolio Value  Total Profits ($)  \
# 0    AMZN              100             148.453911          48.453911
# 1   GOOGL              100             128.749495          28.749495
# 2    MSFT              100             270.989703         170.989703
#
#    Cumulative Return (%)  Sharpe Ratio  Maximum Drawdown (%)
# 0              48.453911      0.865319             31.756736
# 1              28.749495      0.529728             20.416285
# 2             170.989703      1.396928             20.278057

# %%
# Printing the table using tabulate
print("Results with Bayesian Optimization: ")
print(tabulate(table_data, headers=headers))
# Out:
# Results with Bayesian Optimization:
# Dataset      Initial Capital    Final Portfolio Value    Total Profits ($)    Cumulative Return (%)    Sharpe Ratio    Maximum Drawdown (%)
# ---------  -----------------  -----------------------  -------------------  -----------------------  --------------  ----------------------
# AMZN                     100                  134.054              34.0539                  34.0539        0.54709                  25.8248
# GOOGL                    100                  133.287              33.2866                  33.2866        0.553214                 25.9312
# MSFT                     100                  239.08              139.08                   139.08          1.02436                  36.4538
