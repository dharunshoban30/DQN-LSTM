# %% [markdown]
# ## Load Datasets and Libraries
#
# ---------------------------------

# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from collections import deque
import random

from sklearn.model_selection import train_test_split

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Define the paths to the datasets
dataset1_path = r"/content/drive/MyDrive/FYP/AMZN_cleaned.csv"
dataset2_path = r"/content/drive/MyDrive/FYP/GOOGL_cleaned.csv"
dataset3_path = r"/content/drive/MyDrive/FYP/MSFT_cleaned.csv"

# %%
amzn_df = pd.read_csv(dataset1_path)
googl_df = pd.read_csv(dataset2_path)
msft_df = pd.read_csv(dataset3_path)

# %%
amzn_df.head()
# Out:
#       Open     High      Low    Close        SMA        EMA      MACD
# 0  14.1500  14.2100  13.3555  13.6380  13.426175  13.527232  0.161967
# 1  13.5520  13.7970  13.1850  13.2750  13.446650  13.488427  0.129849
# 2  13.4465  13.4465  13.1400  13.2500  13.462950  13.451746  0.101210
# 3  13.1390  13.2340  12.9535  12.9990  13.465025  13.382093  0.057597
# 4  13.1000  13.4015  13.0730  13.3445  13.461100  13.376309  0.050332

# %%
googl_df.head()
# Out:
#         Open       High        Low      Close        SMA        EMA      MACD
# 0  18.862362  19.042793  18.841593  18.864614  18.346121  18.517347  0.163696
# 1  18.781532  18.959459  18.775024  18.911161  18.386712  18.577934  0.182985
# 2  18.973974  19.434435  18.971472  19.409409  18.451689  18.705853  0.235759
# 3  19.211460  19.281031  18.975725  18.994493  18.478028  18.750259  0.241321
# 4  19.047297  19.297047  19.005756  19.162663  18.516804  18.813706  0.256344

# %%
msft_df.head()
# Out:
#         Open       High        Low      Close      SMA        EMA      MACD
# 0  28.010000  28.190001  27.760000  27.850000  27.2260  27.569285  0.130848
# 1  27.790001  27.969999  27.400000  27.450001  27.2175  27.550934  0.111640
# 2  27.670000  28.049999  27.549999  27.930000  27.2515  27.609251  0.133609
# 3  27.870001  28.020000  27.420000  27.440001  27.2865  27.583213  0.110211
# 4  27.620001  27.660000  27.360001  27.500000  27.3270  27.570411  0.095409

# %% [markdown]
# ## Model Construction and Training
#
# ----------------------------------------------------

# %% [markdown]
# ### Define Trading Environment

# %%
class TradingEnv:
    def __init__(self, data, initial_capital=100):
        self.data = data
        self.state_space = ['Open', 'High', 'Low', 'Close', 'SMA', 'EMA', 'MACD']
        self.action_space = ['Sell', 'Hold', 'Buy']
        self.initial_capital = initial_capital
        self.reset()

    def reset(self):
        self.current_step = 0
        self.portfolio_value = self.initial_capital
        self.holding = False
        self.buy_price = 0.0

    def step(self, action):
        current_price = self.data['Close'].iloc[self.current_step]
        reward = 0

        if action == 2:  # Buy
            if not self.holding:
                self.buy_price = current_price
                self.holding = True

        elif action == 0:  # Sell
            if self.holding:
                reward = current_price - self.buy_price
                self.portfolio_value += reward
                self.holding = False

        self.current_step += 1
        done = self.current_step == len(self.data) - 1

        print(f"Action: {self.action_space[action]}, Reward: {reward}, Done: {done}, Portfolio Value: {self.portfolio_value}")

        return reward, done

    def get_state(self):
        return self.data.iloc[self.current_step][self.state_space].values

    def get_portfolio_value(self):
        return self.portfolio_value

# %% [markdown]
# ### Construct DQN-LSTM Model

# %%
class DQN_LSTM(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super(DQN_LSTM, self).__init__()
        self.lstm = nn.LSTM(input_dim, hidden_dim, batch_first=True)
        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, x):
        h_0 = torch.zeros(1, x.size(0), hidden_dim).to(x.device)
        c_0 = torch.zeros(1, x.size(0), hidden_dim).to(x.device)
        out, _ = self.lstm(x, (h_0, c_0))
        out = self.fc(out[:, -1, :])
        return out

# %% [markdown]
# ### Train Model

# %%
def train_dqn_lstm(env, model, optimizer, criterion, num_episodes=5, batch_size=64, gamma=0.95, epsilon=1.0, epsilon_decay=0.995, epsilon_min=0.01):
    memory = deque(maxlen=2000)

    for episode in range(num_episodes):
        env.reset()
        state = torch.tensor(np.array([env.get_state()]), dtype=torch.float32).to(device)
        total_reward = 0

        while True:
            if np.random.rand() <= epsilon:
                action = np.random.choice(len(env.action_space))
            else:
                with torch.no_grad():
                    q_values = model(state.unsqueeze(0))
                    action = torch.argmax(q_values).item()

            reward, done = env.step(action)
            total_reward += reward
            next_state = torch.tensor([env.get_state()], dtype=torch.float32).to(device)
            memory.append((state, action, reward, next_state, done))
            state = next_state

            if done:
                print(f"Episode {episode + 1}/{num_episodes}, Total Reward: {total_reward}, Portfolio Value: {env.get_portfolio_value()}")
                break

            if len(memory) > batch_size:
                batch = random.sample(memory, batch_size)
                for s, a, r, s_next, d in batch:
                    q_update = r
                    if not d:
                        q_update = (r + gamma * torch.max(model(s_next.unsqueeze(0))).item())
                    q_values = model(s.unsqueeze(0))
                    q_values[0][a] = q_update
                    optimizer.zero_grad()
                    loss = criterion(model(s.unsqueeze(0)), q_values)
                    loss.backward()
                    optimizer.step()

        if epsilon > epsilon_min:
            epsilon *= epsilon_decay

    return model

# %% [markdown]
# ## Define Performance Metrics
#
# ----------------------------------------------------

# %%
def evaluate_dqn_lstm(env, model):
    env.reset()
    state = torch.tensor(np.array([env.get_state()]), dtype=torch.float32).to(device)
    portfolio_values = [env.initial_capital]

    while True:
        with torch.no_grad():
            q_values = model(state.unsqueeze(0))
            action = torch.argmax(q_values).item()

        reward, done = env.step(action)
        portfolio_values.append(env.get_portfolio_value())
        state = torch.tensor([env.get_state()], dtype=torch.float32).to(device)

        if done:
            break

    return portfolio_values

def calculate_performance_metrics(portfolio_values, risk_free_rate = 0.01):
    portfolio_values = np.array(portfolio_values)

    # Cumulative Return
    initial_value = portfolio_values[0]
    final_value = portfolio_values[-1]
    cumulative_return = ((final_value - initial_value) / initial_value) * 100

    # Sharpe Ratio
    returns = np.diff(portfolio_values) / portfolio_values[:-1]
    excess_returns = returns - risk_free_rate / 252  # Convert annual risk-free rate to daily
    mean_excess_return = np.mean(excess_returns)
    std_excess_return = np.std(excess_returns)

    # Handle the case where std_excess_return is zero
    if std_excess_return != 0:
        sharpe_ratio = mean_excess_return / std_excess_return * np.sqrt(252)
    else:
        sharpe_ratio = np.nan  # Avoid division by zero

    # Maximum Drawdown
    peak_values = np.maximum.accumulate(portfolio_values)
    drawdowns = (peak_values - portfolio_values) / peak_values
    maximum_drawdown = drawdowns.max() * 100

    return cumulative_return, sharpe_ratio, maximum_drawdown

# %% [markdown]
# ## Evaluate Model
#
# ----------------------------------------------------

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
results = []

input_dim = len(['Open', 'High', 'Low', 'Close', 'SMA', 'EMA', 'MACD'])
hidden_dim = 64
output_dim = 3  # Buy, Sell, Hold
learning_rate = 0.001

datasets = {
    'AMZN': amzn_df,
    'GOOGL': googl_df,
    'MSFT': msft_df
}

for name, data in datasets.items():
    # Clean the data to remove any infinities or NaNs
    data.replace([np.inf, -np.inf], np.nan, inplace=True)
    data.dropna(inplace=True)

    env = TradingEnv(data, initial_capital=100)
    model = DQN_LSTM(input_dim, hidden_dim, output_dim).to(device)
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)
    criterion = nn.MSELoss()

    # Train the model
    model = train_dqn_lstm(env, model, optimizer, criterion)

    # Evaluate the model
    portfolio_values = evaluate_dqn_lstm(env, model)
    total_profits = portfolio_values[-1] - env.initial_capital
    cr, sr, mdd = calculate_performance_metrics(portfolio_values)

    results.append({
        'Dataset': name,
        'Total Profits ($)': total_profits,
        'Cumulative Return (%)': cr,
        'Sharpe Ratio': sr,
        'Maximum Drawdown (%)': mdd
    })

results_df = pd.DataFrame(results)

# Display the results DataFrame
print(results_df)
# Out:
# Streaming output truncated to the last 5000 lines.
# Action: Sell, Reward: 1.1999959999999987, Done: False, Portfolio Value: 107.97997300000006
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 107.97997300000006
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 107.97997300000006
# Action: Sell, Reward: 0.5699999999999932, Done: False, Portfolio Value: 108.54997300000005
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 108.54997300000005
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 108.54997300000005
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 108.54997300000005
# Action: Sell, Reward: 0.7099990000000034, Done: False, Portfolio Value: 109.25997200000006
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 109.25997200000006
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 109.25997200000006
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 109.25997200000006
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 109.25997200000006
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 109.25997200000006
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 109.25997200000006
# Action: Sell, Reward: 0.5099980000000031, Done: False, Portfolio Value: 109.76997000000006
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 109.76997000000006
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 109.76997000000006
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 109.76997000000006
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 109.76997000000006
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 109.76997000000006
# Action: Sell, Reward: -0.7899969999999996, Done: False, Portfolio Value: 108.97997300000006
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 108.97997300000006
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 108.97997300000006
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 108.97997300000006
# Action: Sell, Reward: -0.33000200000000035, Done: False, Portfolio Value: 108.64997100000005
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 108.64997100000005
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 108.64997100000005
# Action: Sell, Reward: -0.5999989999999968, Done: False, Portfolio Value: 108.04997200000005
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 108.04997200000005
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 108.04997200000005
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 108.04997200000005
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 108.04997200000005
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 108.04997200000005
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 108.04997200000005
# Action: Sell, Reward: 0.610001000000004, Done: False, Portfolio Value: 108.65997300000006
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 108.65997300000006
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 108.65997300000006
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 108.65997300000006
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 108.65997300000006
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 108.65997300000006
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 108.65997300000006
# Action: Sell, Reward: -0.6699980000000068, Done: False, Portfolio Value: 107.98997500000006
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 107.98997500000006
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 107.98997500000006
# Action: Sell, Reward: -0.1100009999999969, Done: False, Portfolio Value: 107.87997400000006
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 107.87997400000006
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 107.87997400000006
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 107.87997400000006
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 107.87997400000006
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 107.87997400000006
# Action: Sell, Reward: 0.43999899999999315, Done: False, Portfolio Value: 108.31997300000006
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 108.31997300000006
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 108.31997300000006
# Action: Sell, Reward: 1.0200000000000031, Done: False, Portfolio Value: 109.33997300000007
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 109.33997300000007
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 109.33997300000007
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 109.33997300000007
# Action: Sell, Reward: 5.039997, Done: False, Portfolio Value: 114.37997000000007
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 114.37997000000007
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 114.37997000000007
# Action: Sell, Reward: -0.5200009999999935, Done: False, Portfolio Value: 113.85996900000008
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 113.85996900000008
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 113.85996900000008
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 113.85996900000008
# Action: Sell, Reward: -2.380001, Done: False, Portfolio Value: 111.47996800000007
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 111.47996800000007
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 111.47996800000007
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 111.47996800000007
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 111.47996800000007
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 111.47996800000007
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 111.47996800000007
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 111.47996800000007
# Action: Sell, Reward: 0.6600000000000037, Done: False, Portfolio Value: 112.13996800000007
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 112.13996800000007
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 112.13996800000007
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 112.13996800000007
# Action: Sell, Reward: -0.6799999999999997, Done: False, Portfolio Value: 111.45996800000006
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 111.45996800000006
# Action: Sell, Reward: 1.0200009999999935, Done: False, Portfolio Value: 112.47996900000005
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 112.47996900000005
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 112.47996900000005
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 112.47996900000005
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 112.47996900000005
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 112.47996900000005
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 112.47996900000005
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 112.47996900000005
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 112.47996900000005
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 112.47996900000005
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 112.47996900000005
# Action: Sell, Reward: 0.29999999999999716, Done: False, Portfolio Value: 112.77996900000005
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 112.77996900000005
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 112.77996900000005
# Action: Sell, Reward: 0.3500020000000035, Done: False, Portfolio Value: 113.12997100000005
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 113.12997100000005
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 113.12997100000005
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 113.12997100000005
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 113.12997100000005
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 113.12997100000005
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 113.12997100000005
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 113.12997100000005
# Action: Sell, Reward: -0.9700019999999938, Done: False, Portfolio Value: 112.15996900000006
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 112.15996900000006
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 112.15996900000006
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 112.15996900000006
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 112.15996900000006
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 112.15996900000006
# Action: Sell, Reward: -0.07000000000000028, Done: False, Portfolio Value: 112.08996900000005
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 112.08996900000005
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 112.08996900000005
# Action: Sell, Reward: 0.36999899999999997, Done: False, Portfolio Value: 112.45996800000006
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 112.45996800000006
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 112.45996800000006
# Action: Sell, Reward: 0.21999700000000644, Done: False, Portfolio Value: 112.67996500000007
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 112.67996500000007
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 112.67996500000007
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 112.67996500000007
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 112.67996500000007
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 112.67996500000007
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 112.67996500000007
# Action: Sell, Reward: -0.9799989999999994, Done: False, Portfolio Value: 111.69996600000007
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 111.69996600000007
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 111.69996600000007
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 111.69996600000007
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 111.69996600000007
# Action: Sell, Reward: 1.350003000000001, Done: False, Portfolio Value: 113.04996900000008
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 113.04996900000008
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 113.04996900000008
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 113.04996900000008
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 113.04996900000008
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 113.04996900000008
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 113.04996900000008
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 113.04996900000008
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 113.04996900000008
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 113.04996900000008
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 113.04996900000008
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 113.04996900000008
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 113.04996900000008
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 113.04996900000008
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 113.04996900000008
# Action: Sell, Reward: -4.470000999999996, Done: False, Portfolio Value: 108.57996800000008
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 108.57996800000008
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 108.57996800000008
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 108.57996800000008
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 108.57996800000008
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 108.57996800000008
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 108.57996800000008
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 108.57996800000008
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 108.57996800000008
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 108.57996800000008
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 108.57996800000008
# Action: Sell, Reward: -0.04000099999999662, Done: False, Portfolio Value: 108.53996700000008
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 108.53996700000008
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 108.53996700000008
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 108.53996700000008
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 108.53996700000008
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 108.53996700000008
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 108.53996700000008
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 108.53996700000008
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 108.53996700000008
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 108.53996700000008
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 108.53996700000008
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 108.53996700000008
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 108.53996700000008
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 108.53996700000008
# Action: Sell, Reward: -0.619999, Done: False, Portfolio Value: 107.91996800000007
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 107.91996800000007
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 107.91996800000007
# Action: Sell, Reward: 1.1700019999999967, Done: False, Portfolio Value: 109.08997000000006
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 109.08997000000006
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 109.08997000000006
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 109.08997000000006
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 109.08997000000006
# Action: Sell, Reward: 0.7000010000000003, Done: False, Portfolio Value: 109.78997100000007
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 109.78997100000007
# Action: Sell, Reward: -0.1100009999999969, Done: False, Portfolio Value: 109.67997000000007
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 109.67997000000007
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 109.67997000000007
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 109.67997000000007
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 109.67997000000007
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 109.67997000000007
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 109.67997000000007
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 109.67997000000007
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 109.67997000000007
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 109.67997000000007
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 109.67997000000007
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 109.67997000000007
# Action: Sell, Reward: 6.360000999999997, Done: False, Portfolio Value: 116.03997100000007
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 116.03997100000007
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 116.03997100000007
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 116.03997100000007
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 116.03997100000007
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 116.03997100000007
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 116.03997100000007
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 116.03997100000007
# Action: Sell, Reward: -0.22000100000000344, Done: False, Portfolio Value: 115.81997000000007
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 115.81997000000007
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 115.81997000000007
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 115.81997000000007
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 115.81997000000007
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 115.81997000000007
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 115.81997000000007
# Action: Sell, Reward: 0.19999599999999873, Done: False, Portfolio Value: 116.01996600000007
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 116.01996600000007
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 116.01996600000007
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 116.01996600000007
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 116.01996600000007
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 116.01996600000007
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 116.01996600000007
# Action: Sell, Reward: 0.41999799999999965, Done: False, Portfolio Value: 116.43996400000006
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 116.43996400000006
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 116.43996400000006
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 116.43996400000006
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 116.43996400000006
# Action: Sell, Reward: -0.09999899999999684, Done: False, Portfolio Value: 116.33996500000006
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 116.33996500000006
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 116.33996500000006
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 116.33996500000006
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 116.33996500000006
# Action: Sell, Reward: -0.13000100000000003, Done: False, Portfolio Value: 116.20996400000007
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 116.20996400000007
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 116.20996400000007
# Action: Sell, Reward: -0.4299999999999997, Done: False, Portfolio Value: 115.77996400000006
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 115.77996400000006
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 115.77996400000006
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 115.77996400000006
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 115.77996400000006
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 115.77996400000006
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 115.77996400000006
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 115.77996400000006
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 115.77996400000006
# Action: Sell, Reward: -0.47000100000000344, Done: False, Portfolio Value: 115.30996300000007
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 115.30996300000007
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 115.30996300000007
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 115.30996300000007
# Action: Sell, Reward: -1.880001, Done: False, Portfolio Value: 113.42996200000007
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 113.42996200000007
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 113.42996200000007
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 113.42996200000007
# Action: Sell, Reward: -1.1399999999999935, Done: False, Portfolio Value: 112.28996200000009
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 112.28996200000009
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 112.28996200000009
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 112.28996200000009
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 112.28996200000009
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 112.28996200000009
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 112.28996200000009
# Action: Sell, Reward: 1.3100009999999997, Done: False, Portfolio Value: 113.59996300000009
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 113.59996300000009
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 113.59996300000009
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 113.59996300000009
# Action: Sell, Reward: 3.869999, Done: False, Portfolio Value: 117.4699620000001
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 117.4699620000001
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 117.4699620000001
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 117.4699620000001
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 117.4699620000001
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 117.4699620000001
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 117.4699620000001
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 117.4699620000001
# Action: Sell, Reward: -2.2900009999999966, Done: False, Portfolio Value: 115.1799610000001
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 115.1799610000001
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 115.1799610000001
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 115.1799610000001
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 115.1799610000001
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 115.1799610000001
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 115.1799610000001
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 115.1799610000001
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 115.1799610000001
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 115.1799610000001
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 115.1799610000001
# Action: Sell, Reward: -1.350003000000001, Done: False, Portfolio Value: 113.8299580000001
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 113.8299580000001
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 113.8299580000001
# Action: Sell, Reward: 2.0700000000000003, Done: False, Portfolio Value: 115.89995800000011
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 115.89995800000011
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 115.89995800000011
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 115.89995800000011
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 115.89995800000011
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 115.89995800000011
# Action: Sell, Reward: 1.0200000000000031, Done: False, Portfolio Value: 116.91995800000012
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 116.91995800000012
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 116.91995800000012
# Action: Sell, Reward: 0.5200000000000031, Done: False, Portfolio Value: 117.43995800000013
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 117.43995800000013
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 117.43995800000013
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 117.43995800000013
# Action: Sell, Reward: 0.36999899999999997, Done: False, Portfolio Value: 117.80995700000014
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 117.80995700000014
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 117.80995700000014
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 117.80995700000014
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 117.80995700000014
# Action: Sell, Reward: 1.1699980000000068, Done: False, Portfolio Value: 118.97995500000015
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 118.97995500000015
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 118.97995500000015
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 118.97995500000015
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 118.97995500000015
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 118.97995500000015
# Action: Sell, Reward: -0.31000099999999975, Done: False, Portfolio Value: 118.66995400000015
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 118.66995400000015
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 118.66995400000015
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 118.66995400000015
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 118.66995400000015
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 118.66995400000015
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 118.66995400000015
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 118.66995400000015
# Action: Sell, Reward: 2.1499980000000036, Done: False, Portfolio Value: 120.81995200000014
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 120.81995200000014
# Action: Sell, Reward: -0.7999989999999997, Done: False, Portfolio Value: 120.01995300000014
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 120.01995300000014
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 120.01995300000014
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 120.01995300000014
# Action: Sell, Reward: -4.339999999999996, Done: False, Portfolio Value: 115.67995300000015
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 115.67995300000015
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 115.67995300000015
# Action: Sell, Reward: -1.0700000000000003, Done: False, Portfolio Value: 114.60995300000016
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 114.60995300000016
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 114.60995300000016
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 114.60995300000016
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 114.60995300000016
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 114.60995300000016
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 114.60995300000016
# Action: Sell, Reward: 0.9500000000000028, Done: False, Portfolio Value: 115.55995300000016
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 115.55995300000016
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 115.55995300000016
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 115.55995300000016
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 115.55995300000016
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 115.55995300000016
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 115.55995300000016
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 115.55995300000016
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 115.55995300000016
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 115.55995300000016
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 115.55995300000016
# Action: Sell, Reward: 0.5299989999999966, Done: False, Portfolio Value: 116.08995200000015
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 116.08995200000015
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 116.08995200000015
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 116.08995200000015
# Action: Sell, Reward: 0.5299979999999991, Done: False, Portfolio Value: 116.61995000000016
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 116.61995000000016
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 116.61995000000016
# Action: Sell, Reward: -0.34999899999999684, Done: False, Portfolio Value: 116.26995100000016
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 116.26995100000016
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 116.26995100000016
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 116.26995100000016
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 116.26995100000016
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 116.26995100000016
# Action: Sell, Reward: -0.30999700000000274, Done: False, Portfolio Value: 115.95995400000015
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 115.95995400000015
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 115.95995400000015
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 115.95995400000015
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 115.95995400000015
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 115.95995400000015
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 115.95995400000015
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 115.95995400000015
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 115.95995400000015
# Action: Sell, Reward: -1.4000020000000006, Done: False, Portfolio Value: 114.55995200000015
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 114.55995200000015
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 114.55995200000015
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 114.55995200000015
# Action: Sell, Reward: 0.619999, Done: False, Portfolio Value: 115.17995100000016
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 115.17995100000016
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 115.17995100000016
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 115.17995100000016
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 115.17995100000016
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 115.17995100000016
# Action: Sell, Reward: 1.8299980000000033, Done: False, Portfolio Value: 117.00994900000016
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 117.00994900000016
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 117.00994900000016
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 117.00994900000016
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 117.00994900000016
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 117.00994900000016
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 117.00994900000016
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 117.00994900000016
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 117.00994900000016
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 117.00994900000016
# Action: Sell, Reward: 2.7999989999999997, Done: False, Portfolio Value: 119.80994800000016
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 119.80994800000016
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 119.80994800000016
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 119.80994800000016
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 119.80994800000016
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 119.80994800000016
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 119.80994800000016
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 119.80994800000016
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 119.80994800000016
# Action: Sell, Reward: 0.10000199999999637, Done: False, Portfolio Value: 119.90995000000015
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 119.90995000000015
# Action: Sell, Reward: -0.1800009999999972, Done: False, Portfolio Value: 119.72994900000015
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 119.72994900000015
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 119.72994900000015
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 119.72994900000015
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 119.72994900000015
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 119.72994900000015
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 119.72994900000015
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 119.72994900000015
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 119.72994900000015
# Action: Sell, Reward: 0.29000100000000373, Done: False, Portfolio Value: 120.01995000000015
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 120.01995000000015
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 120.01995000000015
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 120.01995000000015
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 120.01995000000015
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 120.01995000000015
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 120.01995000000015
# Action: Sell, Reward: -0.3600009999999969, Done: False, Portfolio Value: 119.65994900000015
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 119.65994900000015
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 119.65994900000015
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 119.65994900000015
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 119.65994900000015
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 119.65994900000015
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 119.65994900000015
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 119.65994900000015
# Action: Sell, Reward: -1.3500029999999938, Done: False, Portfolio Value: 118.30994600000017
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 118.30994600000017
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 118.30994600000017
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 118.30994600000017
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 118.30994600000017
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 118.30994600000017
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 118.30994600000017
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 118.30994600000017
# Action: Sell, Reward: -0.9199979999999996, Done: False, Portfolio Value: 117.38994800000017
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 117.38994800000017
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 117.38994800000017
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 117.38994800000017
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 117.38994800000017
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 117.38994800000017
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 117.38994800000017
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 117.38994800000017
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 117.38994800000017
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 117.38994800000017
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 117.38994800000017
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 117.38994800000017
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 117.38994800000017
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 117.38994800000017
# Action: Sell, Reward: -0.38000100000000003, Done: False, Portfolio Value: 117.00994700000018
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 117.00994700000018
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 117.00994700000018
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 117.00994700000018
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 117.00994700000018
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 117.00994700000018
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 117.00994700000018
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 117.00994700000018
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 117.00994700000018
# Action: Sell, Reward: 2.879996999999996, Done: False, Portfolio Value: 119.88994400000018
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 119.88994400000018
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 119.88994400000018
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 119.88994400000018
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 119.88994400000018
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 119.88994400000018
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 119.88994400000018
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 119.88994400000018
# Action: Sell, Reward: 1.260002, Done: False, Portfolio Value: 121.14994600000018
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 121.14994600000018
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 121.14994600000018
# Action: Sell, Reward: 0.3199990000000028, Done: False, Portfolio Value: 121.4699450000002
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 121.4699450000002
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 121.4699450000002
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 121.4699450000002
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 121.4699450000002
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 121.4699450000002
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 121.4699450000002
# Action: Sell, Reward: 3.0, Done: False, Portfolio Value: 124.4699450000002
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 124.4699450000002
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 124.4699450000002
# Action: Sell, Reward: 0.20999899999999627, Done: False, Portfolio Value: 124.67994400000019
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 124.67994400000019
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 124.67994400000019
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 124.67994400000019
# Action: Sell, Reward: 0.04999899999999968, Done: False, Portfolio Value: 124.72994300000019
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 124.72994300000019
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 124.72994300000019
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 124.72994300000019
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 124.72994300000019
# Action: Sell, Reward: 2.020000000000003, Done: False, Portfolio Value: 126.7499430000002
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 126.7499430000002
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 126.7499430000002
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 126.7499430000002
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 126.7499430000002
# Action: Sell, Reward: -0.28000300000000067, Done: False, Portfolio Value: 126.46994000000021
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 126.46994000000021
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 126.46994000000021
# Action: Sell, Reward: -0.07999800000000334, Done: False, Portfolio Value: 126.3899420000002
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 126.3899420000002
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 126.3899420000002
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 126.3899420000002
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 126.3899420000002
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 126.3899420000002
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 126.3899420000002
# Action: Sell, Reward: 0.44000299999999726, Done: False, Portfolio Value: 126.82994500000021
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 126.82994500000021
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 126.82994500000021
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 126.82994500000021
# Action: Sell, Reward: -0.20000100000000032, Done: False, Portfolio Value: 126.62994400000021
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 126.62994400000021
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 126.62994400000021
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 126.62994400000021
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 126.62994400000021
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 126.62994400000021
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 126.62994400000021
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 126.62994400000021
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 126.62994400000021
# Action: Sell, Reward: 0.3400000000000034, Done: False, Portfolio Value: 126.96994400000021
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 126.96994400000021
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 126.96994400000021
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 126.96994400000021
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 126.96994400000021
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 126.96994400000021
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 126.96994400000021
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 126.96994400000021
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 126.96994400000021
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 126.96994400000021
# Action: Sell, Reward: -1.489998, Done: False, Portfolio Value: 125.47994600000021
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 125.47994600000021
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 125.47994600000021
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 125.47994600000021
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 125.47994600000021
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 125.47994600000021
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 125.47994600000021
# Action: Sell, Reward: 1.099999000000004, Done: False, Portfolio Value: 126.57994500000021
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 126.57994500000021
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 126.57994500000021
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 126.57994500000021
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 126.57994500000021
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 126.57994500000021
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 126.57994500000021
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 126.57994500000021
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 126.57994500000021
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 126.57994500000021
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 126.57994500000021
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 126.57994500000021
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 126.57994500000021
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 126.57994500000021
# Action: Sell, Reward: 1.009998000000003, Done: False, Portfolio Value: 127.5899430000002
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 127.5899430000002
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 127.5899430000002
# Action: Sell, Reward: -0.22000100000001055, Done: False, Portfolio Value: 127.3699420000002
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 127.3699420000002
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 127.3699420000002
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 127.3699420000002
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 127.3699420000002
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 127.3699420000002
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 127.3699420000002
# Action: Sell, Reward: 0.1599960000000067, Done: False, Portfolio Value: 127.5299380000002
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 127.5299380000002
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 127.5299380000002
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 127.5299380000002
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 127.5299380000002
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 127.5299380000002
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 127.5299380000002
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 127.5299380000002
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 127.5299380000002
# Action: Sell, Reward: 0.4400019999999927, Done: False, Portfolio Value: 127.9699400000002
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 127.9699400000002
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 127.9699400000002
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 127.9699400000002
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 127.9699400000002
# Action: Sell, Reward: -0.19999700000001042, Done: False, Portfolio Value: 127.76994300000018
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 127.76994300000018
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 127.76994300000018
# Action: Sell, Reward: 0.5300060000000002, Done: False, Portfolio Value: 128.2999490000002
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 128.2999490000002
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 128.2999490000002
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 128.2999490000002
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 128.2999490000002
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 128.2999490000002
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 128.2999490000002
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 128.2999490000002
# Action: Sell, Reward: 2.8799980000000005, Done: False, Portfolio Value: 131.1799470000002
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 131.1799470000002
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 131.1799470000002
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 131.1799470000002
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 131.1799470000002
# Action: Sell, Reward: -0.6000060000000076, Done: False, Portfolio Value: 130.5799410000002
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 130.5799410000002
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 130.5799410000002
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 130.5799410000002
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 130.5799410000002
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 130.5799410000002
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 130.5799410000002
# Action: Sell, Reward: -0.5100020000000001, Done: False, Portfolio Value: 130.0699390000002
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 130.0699390000002
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 130.0699390000002
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 130.0699390000002
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 130.0699390000002
# Action: Sell, Reward: 0.7399979999999999, Done: False, Portfolio Value: 130.80993700000022
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 130.80993700000022
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 130.80993700000022
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 130.80993700000022
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 130.80993700000022
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 130.80993700000022
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 130.80993700000022
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 130.80993700000022
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 130.80993700000022
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 130.80993700000022
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 130.80993700000022
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 130.80993700000022
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 130.80993700000022
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 130.80993700000022
# Action: Sell, Reward: -2.739998, Done: False, Portfolio Value: 128.0699390000002
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 128.0699390000002
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 128.0699390000002
# Action: Sell, Reward: -0.75, Done: False, Portfolio Value: 127.3199390000002
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 127.3199390000002
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 127.3199390000002
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 127.3199390000002
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 127.3199390000002
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 127.3199390000002
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 127.3199390000002
# Action: Sell, Reward: 0.26000200000000007, Done: False, Portfolio Value: 127.5799410000002
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 127.5799410000002
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 127.5799410000002
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 127.5799410000002
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 127.5799410000002
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 127.5799410000002
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 127.5799410000002
# Action: Sell, Reward: -0.5100020000000001, Done: False, Portfolio Value: 127.0699390000002
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 127.0699390000002
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 127.0699390000002
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 127.0699390000002
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 127.0699390000002
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 127.0699390000002
# Action: Sell, Reward: 2.7900010000000037, Done: False, Portfolio Value: 129.85994000000022
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 129.85994000000022
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 129.85994000000022
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 129.85994000000022
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 129.85994000000022
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 129.85994000000022
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 129.85994000000022
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 129.85994000000022
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 129.85994000000022
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 129.85994000000022
# Action: Hold, Reward: 0, Done: False, Portfolio Value: 129.85994000000022
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 129.85994000000022
# Action: Buy, Reward: 0, Done: False, Portfolio Value: 129.85994000000022
# ...
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: False, Portfolio Value: 100
# Action: Sell, Reward: 0, Done: True, Portfolio Value: 100
#   Dataset  Total Profits ($)  Cumulative Return (%)  Sharpe Ratio  \
# 0    AMZN           99.34951               99.34951      0.269013
# 1   GOOGL            0.00000                0.00000           NaN
# 2    MSFT            0.00000                0.00000           NaN
#
#    Maximum Drawdown (%)
# 0             18.996381
# 1              0.000000
# 2              0.000000

# %% [markdown]
# ## Results Analysis
#
# ----------------------------------------------------

# %%
results_df
# Out:
#   Dataset  Total Profits ($)  Cumulative Return (%)  Sharpe Ratio  \
# 0    AMZN           99.34951               99.34951      0.269013
# 1   GOOGL            0.00000                0.00000           NaN
# 2    MSFT            0.00000                0.00000           NaN
#
#    Maximum Drawdown (%)
# 0             18.996381
# 1              0.000000
# 2              0.000000
